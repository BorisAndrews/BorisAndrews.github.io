# %% [markdown]
# # **LINEAR ELASTICITY, MATERIAL ROBUSTNESS & BGG**
#
# <!-- 2D rectangular beam. Fixed on the left and right face, traction-free on the top and bottom.
#
# Two Hellinger–Reissner mixed schemes are implemented and can be selected at runtime:
# - **JM** (Johnson–Mercier): symmetric $P_1$ stress in $H(\operatorname{div})$, $P_0$ displacement.
# - **AFW** (Arnold–Falk–Winther): $[BDM_1]^2$ stress with *weakly imposed* symmetry, $P_0$ displacement, scalar $DG_0$ skew-rotation variable $\gamma$. -->

# %% [markdown]
# ## **Imports**

# %%
try:
    # !wget "https://fem-on-colab.github.io/releases/firedrake-install-development-real.sh" -O "/tmp/firedrake-install.sh"
    # !bash "/tmp/firedrake-install.sh"
    from firedrake import *  # noqa: F401
except:
    from firedrake import *  # noqa: F401
# Out:
# --2026-06-02 12:01:14--  https://fem-on-colab.github.io/releases/firedrake-install-development-real.sh
# Resolving fem-on-colab.github.io (fem-on-colab.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to fem-on-colab.github.io (fem-on-colab.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4775 (4.7K) [application/x-sh]
# Saving to: ‘/tmp/firedrake-install.sh’
#
# /tmp/firedrake-inst 100%[===================>]   4.66K  --.-KB/s    in 0s
#
# 2026-06-02 12:01:14 (34.6 MB/s) - ‘/tmp/firedrake-install.sh’ saved [4775/4775]
#
# + INSTALL_PREFIX=/usr/local
# ++ echo /usr/local
# ++ awk -F/ '{print NF-1}'
# + INSTALL_PREFIX_DEPTH=2
# + PROJECT_NAME=fem-on-colab
# + SHARE_PREFIX=/usr/local/share/fem-on-colab
# + FIREDRAKE_INSTALLED=/usr/local/share/fem-on-colab/firedrake.installed
# + [[ ! -f /usr/local/share/fem-on-colab/firedrake.installed ]]
# + PYBIND11_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f823fc81/releases/pybind11-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f823fc81/releases/pybind11-install.sh == http* ]]
# + PYBIND11_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f823fc81/releases/pybind11-install.sh
# + PYBIND11_INSTALL_SCRIPT_PATH=/tmp/pybind11-install.sh
# + [[ ! -f /tmp/pybind11-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f823fc81/releases/pybind11-install.sh -O /tmp/pybind11-install.sh
# --2026-06-02 12:01:14--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f823fc81/releases/pybind11-install.sh
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f823fc81113f282acc3b33bbadaf7244c914c074/releases/pybind11-install.sh [following]
# --2026-06-02 12:01:14--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f823fc81113f282acc3b33bbadaf7244c914c074/releases/pybind11-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800 (1.8K) [text/plain]
# Saving to: ‘/tmp/pybind11-install.sh’
#
# /tmp/pybind11-insta 100%[===================>]   1.76K  --.-KB/s    in 0s
#
# 2026-06-02 12:01:15 (23.7 MB/s) - ‘/tmp/pybind11-install.sh’ saved [1800/1800]
#
# + source /tmp/pybind11-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ PYBIND11_INSTALLED=/usr/local/share/fem-on-colab/pybind11.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/pybind11.installed ]]
# ++ MPI4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f0593765/releases/mpi4py-install.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f0593765/releases/mpi4py-install.sh == http* ]]
# ++ MPI4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f0593765/releases/mpi4py-install.sh
# ++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++ [[ ! -f /tmp/mpi4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f0593765/releases/mpi4py-install.sh -O /tmp/mpi4py-install.sh
# --2026-06-02 12:01:15--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/f0593765/releases/mpi4py-install.sh
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f059376588e9769072361ba538e7eb5e9a541dd4/releases/mpi4py-install.sh [following]
# --2026-06-02 12:01:15--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/f059376588e9769072361ba538e7eb5e9a541dd4/releases/mpi4py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2583 (2.5K) [text/plain]
# Saving to: ‘/tmp/mpi4py-install.sh’
#
# /tmp/mpi4py-install 100%[===================>]   2.52K  --.-KB/s    in 0s
#
# 2026-06-02 12:01:15 (33.6 MB/s) - ‘/tmp/mpi4py-install.sh’ saved [2583/2583]
#
# ++ source /tmp/mpi4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# +++ GCC_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e8554b69/releases/gcc-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e8554b69/releases/gcc-install.sh == http* ]]
# +++ GCC_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e8554b69/releases/gcc-install.sh
# +++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# +++ [[ ! -f /tmp/gcc-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e8554b69/releases/gcc-install.sh -O /tmp/gcc-install.sh
# --2026-06-02 12:01:15--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/e8554b69/releases/gcc-install.sh
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/e8554b694dc743e503f92713364c48e48137729d/releases/gcc-install.sh [following]
# --2026-06-02 12:01:15--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/e8554b694dc743e503f92713364c48e48137729d/releases/gcc-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8358 (8.2K) [text/plain]
# Saving to: ‘/tmp/gcc-install.sh’
#
# /tmp/gcc-install.sh 100%[===================>]   8.16K  --.-KB/s    in 0s
#
# 2026-06-02 12:01:15 (63.5 MB/s) - ‘/tmp/gcc-install.sh’ saved [8358/8358]
#
# +++ source /tmp/gcc-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ -e /usr/local/lib64 ]]
# ++++ ln -s /usr/local/lib /usr/local/lib64
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ ! -d /usr/local/lib64 ]]
# ++++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++++ GCC_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260506-174453-a8bef73/gcc-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260506-174453-a8bef73/gcc-install.tar.gz == http* ]]
# ++++ GCC_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260506-174453-a8bef73/gcc-install.tar.gz
# ++++ GCC_ARCHIVE_PATH=/tmp/gcc-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260506-174453-a8bef73/gcc-install.tar.gz -O /tmp/gcc-install.tar.gz
# --2026-06-02 12:01:15--  https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20260506-174453-a8bef73/gcc-install.tar.gz
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/92ed192c-9e34-4ad1-a23c-aa39e778701e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A59%3A32Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A59%3A14Z&ske=2026-06-02T12%3A59%3A32Z&sks=b&skv=2018-11-09&sig=scojhpDEAdS91x61OuGyWLBueKt6KHfAneS%2BmeYT%2FA8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwNTI3NiwibmJmIjoxNzgwNDAxNjc2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.24rkWJWuJF-Bm73EhkZ_f3AAKAGNsHis2RZmsOA0Gt4&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-06-02 12:01:16--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/92ed192c-9e34-4ad1-a23c-aa39e778701e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A59%3A32Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A59%3A14Z&ske=2026-06-02T12%3A59%3A32Z&sks=b&skv=2018-11-09&sig=scojhpDEAdS91x61OuGyWLBueKt6KHfAneS%2BmeYT%2FA8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwNTI3NiwibmJmIjoxNzgwNDAxNjc2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.24rkWJWuJF-Bm73EhkZ_f3AAKAGNsHis2RZmsOA0Gt4&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 688117521 (656M) [application/octet-stream]
# Saving to: ‘/tmp/gcc-install.tar.gz’
#
# /tmp/gcc-install.ta 100%[===================>] 656.24M   121MB/s    in 5.9s
#
# 2026-06-02 12:01:21 (112 MB/s) - ‘/tmp/gcc-install.tar.gz’ saved [688117521/688117521]
#
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ tar -xzf /tmp/gcc-install.tar.gz --strip-components=2 --directory=/usr/local
# ++++ apt install -y -qq zlib1g-dev
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ for LEGACY_GPP in /usr/bin/g++-*
# +++++ /usr/bin/g++-11 -dumpversion
# ++++ LEGACY_GCC_VERSION=11
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-11 11
# update-alternatives: using /usr/bin/g++-11 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 11
# update-alternatives: using /usr/bin/gcc-11 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/bin/gcc-ar-11 11
# update-alternatives: using /usr/bin/gcc-ar-11 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/bin/gcc-nm-11 11
# update-alternatives: using /usr/bin/gcc-nm-11 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/bin/gcc-ranlib-11 11
# update-alternatives: using /usr/bin/gcc-ranlib-11 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/bin/x86_64-linux-gnu-g++-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-g++-11 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/bin/x86_64-linux-gnu-gcc-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-11 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/bin/x86_64-linux-gnu-gcc-ar-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ar-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/bin/x86_64-linux-gnu-gcc-nm-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-nm-11 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# +++++ /usr/local/bin/g++ -dumpversion
# ++++ GCC_VERSION=12
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/local/bin/g++-12 12
# update-alternatives: using /usr/local/bin/g++-12 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/local/bin/gcc-12 12
# update-alternatives: using /usr/local/bin/gcc-12 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/local/bin/gcc-ar-12 12
# update-alternatives: using /usr/local/bin/gcc-ar-12 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/local/bin/gcc-nm-12 12
# update-alternatives: using /usr/local/bin/gcc-nm-12 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/local/bin/gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/gcc-ranlib-12 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/gfortran gfortran /usr/local/bin/gfortran-12 12
# update-alternatives: using /usr/local/bin/gfortran-12 to provide /usr/bin/gfortran (gfortran) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-g++-12 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-12 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# ++++ update-alternatives --set g++ /usr/local/bin/g++-12
# ++++ update-alternatives --set gcc /usr/local/bin/gcc-12
# ++++ update-alternatives --set gcc-ar /usr/local/bin/gcc-ar-12
# ++++ update-alternatives --set gcc-nm /usr/local/bin/gcc-nm-12
# ++++ update-alternatives --set gcc-ranlib /usr/local/bin/gcc-ranlib-12
# ++++ update-alternatives --set gfortran /usr/local/bin/gfortran-12
# ++++ update-alternatives --set x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# +++++ which python3
# ++++ PYTHON_EXEC=/usr/bin/python3
# +++++ dirname /usr/bin/python3
# ++++ PYTHON_EXEC_DIR=/usr/bin
# +++++ objdump -x /usr/bin/python3
# +++++ sed 's| ||g'
# +++++ grep 'R.*PATH'
# +++++ sed 's|$ORIGIN|/usr/bin|g'
# +++++ sed 's|R.*PATH||g'
# ++++ PYTHON_RPATH=
# ++++ [[ -z '' ]]
# ++++ PYTHON_RPATH=/usr/lib/x86_64-linux-gnu
# ++++ INSTALL_PREFIX_RPATH=/usr/local/lib
# ++++ [[ -L /usr/lib/x86_64-linux-gnu/libstdc++.so ]]
# +++++ basename /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30
# ++++ LIBSTDCXX_SYSTEM_VERSION=libstdc++.so.6.0.30
# +++++ basename /usr/local/lib/libstdc++.so.6.0.30 /usr/local/lib/libstdc++.so.6.0.30-gdb.py
# ++++ LIBSTDCXX_INSTALL_PREFIX_VERSION=libstdc++.so.6.0.30
# ++++ [[ libstdc++.so.6.0.30 != \l\i\b\s\t\d\c\+\+\.\s\o\.\6\.\0\.\3\0 ]]
# ++++ mkdir -p /usr/local/share/fem-on-colab
# ++++ touch /usr/local/share/fem-on-colab/gcc.installed
# +++ MPI4PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20
  https://github.com/fem-on-colab/fem-on-colab/releases/download/vtk-20260507-104744-4642542/vtk-install.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/449847ca-7cf8-4069-9ce7-2a7a26b26717?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A57%3A30Z&rscd=attachment%3B+filename%3Dvtk-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A57%3A13Z&ske=2026-06-02T12%3A57%3A30Z&sks=b&skv=2018-11-09&sig=clBxiNEVqBu7zuNajMvuGEtxjKu77PnbXnnUIDtOfTc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwNTM0NSwibmJmIjoxNzgwNDAxNzQ1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.UMTfdYLr23i9W2VFdG0MIYYAJ7KH77V6v5l_pIUDhiw&response-content-disposition=attachment%3B%20filename%3Dvtk-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-06-02 12:02:25--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/449847ca-7cf8-4069-9ce7-2a7a26b26717?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A57%3A30Z&rscd=attachment%3B+filename%3Dvtk-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A57%3A13Z&ske=2026-06-02T12%3A57%3A30Z&sks=b&skv=2018-11-09&sig=clBxiNEVqBu7zuNajMvuGEtxjKu77PnbXnnUIDtOfTc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwNTM0NSwibmJmIjoxNzgwNDAxNzQ1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.UMTfdYLr23i9W2VFdG0MIYYAJ7KH77V6v5l_pIUDhiw&response-content-disposition=attachment%3B%20filename%3Dvtk-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163558434 (156M) [application/octet-stream]
# Saving to: ‘/tmp/vtk-install.tar.gz’
#
# /tmp/vtk-install.ta 100%[===================>] 155.98M   143MB/s    in 1.1s
#
# 2026-06-02 12:02:26 (143 MB/s) - ‘/tmp/vtk-install.tar.gz’ saved [163558434/163558434]
#
# ++ [[ /tmp/vtk-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/vtk-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ apt install -y -qq libegl1 libgl1-mesa-dri
# libegl1 is already the newest version (1.4.0-1).
# libgl1-mesa-dri is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgl1-mesa-dri set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/vtk.installed
# + FIREDRAKE_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/firedrake-20260530-015523-b80157f-development-real/firedrake-install.tar.gz
# + [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/firedrake-20260530-015523-b80157f-development-real/firedrake-install.tar.gz == http* ]]
# + FIREDRAKE_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/firedrake-20260530-015523-b80157f-development-real/firedrake-install.tar.gz
# + FIREDRAKE_ARCHIVE_PATH=/tmp/firedrake-install.tar.gz
# + wget https://github.com/fem-on-colab/fem-on-colab/releases/download/firedrake-20260530-015523-b80157f-development-real/firedrake-install.tar.gz -O /tmp/firedrake-install.tar.gz
# --2026-06-02 12:02:39--  https://github.com/fem-on-colab/fem-on-colab/releases/download/firedrake-20260530-015523-b80157f-development-real/firedrake-install.tar.gz
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/a83ec608-1d79-4227-8bf0-f151ac03a087?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A43%3A24Z&rscd=attachment%3B+filename%3Dfiredrake-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A42%3A33Z&ske=2026-06-02T12%3A43%3A24Z&sks=b&skv=2018-11-09&sig=lRM7IXoSA%2FkvAXgKiJ7qPvUklQqGsKni5bO1Ny6CTrc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwMzU2MCwibmJmIjoxNzgwNDAxNzYwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4s-2FPKdl3Qjbmn4chpUdg8mk4HkOWEh7l8bVQu_-7E&response-content-disposition=attachment%3B%20filename%3Dfiredrake-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2026-06-02 12:02:40--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/a83ec608-1d79-4227-8bf0-f151ac03a087?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-02T12%3A43%3A24Z&rscd=attachment%3B+filename%3Dfiredrake-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-02T11%3A42%3A33Z&ske=2026-06-02T12%3A43%3A24Z&sks=b&skv=2018-11-09&sig=lRM7IXoSA%2FkvAXgKiJ7qPvUklQqGsKni5bO1Ny6CTrc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQwMzU2MCwibmJmIjoxNzgwNDAxNzYwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4s-2FPKdl3Qjbmn4chpUdg8mk4HkOWEh7l8bVQu_-7E&response-content-disposition=attachment%3B%20filename%3Dfiredrake-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79432884 (76M) [application/octet-stream]
# Saving to: ‘/tmp/firedrake-install.tar.gz’
#
# /tmp/firedrake-inst 100%[===================>]  75.75M   108MB/s    in 0.7s
#
# 2026-06-02 12:02:40 (108 MB/s) - ‘/tmp/firedrake-install.tar.gz’ saved [79432884/79432884]
#
# + [[ /tmp/firedrake-install.tar.gz != skip ]]
# + rm -rf '/usr/lib/python*/*-packages/Cython*'
# + rm -rf /usr/local/lib/python3.12/dist-packages/Cython /usr/local/lib/python3.12/dist-packages/Cython-3.0.12.dist-info /usr/local/lib/python3.12/dist-packages/Cython.libs
# + rm -rf '/usr/lib/python*/*-packages/netCDF4*'
# + rm -rf '/usr/local/lib/python*/*-packages/netCDF4*'
# + tar -xzf /tmp/firedrake-install.tar.gz --strip-components=2 --directory=/usr/local
# + apt install -y -qq fonts-dejavu graphviz libgraphviz-dev poppler-utils
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk1.0-0 libatk1.0-data
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxcomposite1 libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   fonts-dejavu fonts-dejavu-core fonts-dejavu-extra libatk1.0-0 libatk1.0-data
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgvc6-plugins-gtk librsvg2-common libxcomposite1 libxdot4
#   poppler-utils
# 0 upgraded, 16 newly installed, 0 to remove and 2 not upgraded.
# Need to get 5,767 kB of archives.
# After this operation, 19.4 MB of additional disk space will be used.
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 118252 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../02-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../03-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../04-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../05-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../06-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../07-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../08-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../09-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../10-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../11-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../12-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../13-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../14-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../15-poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.5) ...
# + mkdir -p /usr/local/share/fem-on-colab
# + touch /usr/local/share/fem-on-colab/firedrake.installed
# + set +x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ################################################################################
# #     This installation is offered by FEM on Colab, an open-source project     #
# #       developed and maintained at Università Cattolica del Sacro Cuore       #
# #   by Prof. Francesco Ballarin. Please see https://fem-on-colab.github.io/    #
# #       for more details, including a list of further available packages       #
# #       and how to sponsor the development or contribute to the project.       #
# #                                                                              #
# #   We are conducting an informal survey on FEM on Colab usage by our users.   #
# #   The survey is anonymous, and its compilation will typically only require   #
# #   a couple of minutes of your time. If you wish, give us your feedback at    #
# #                     https://forms.gle/36sZZWNvPpUv8XWr7                      #
# ################################################################################

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Functions**

# %%
def solve_elasticity(scheme="JM", length=10.0, height=1.0, nu=0.3, nx=20, ny=20, shear=1.0, grav=0.0, free_surf=(3,4)):
    # Mesh
    mesh = RectangleMesh(nx, ny, length, height)
    x, y = SpatialCoordinate(mesh)
    d = 2

    # Material parameters
    nu_c  = Constant(nu)
    mu    = 1 / (2*(1 + nu_c))
    lmbda = nu_c / ((1 + nu_c) * (1 - 2*nu_c))
    def A_comp(s):
        # Compliance tensor
        return (1/(2*mu))*sym(s) - (lmbda/(2*mu*(2*mu + d*lmbda)))*tr(s)*Identity(d)

    # Function spaces + functions
    DG_vec = VectorFunctionSpace(mesh, "DG", 0, variant="alfeld")
    if scheme == "JM":
        JM = FunctionSpace(mesh, "JM", 1)
        W  = JM * DG_vec
        sigma, u_0 = TrialFunctions(W)
        tau,   v   = TestFunctions(W)
    elif scheme == "AFW":
        AFW_elem = VectorElement(FiniteElement("BDM", mesh.ufl_cell(), 1, variant="alfeld"), dim=2)
        AFW = FunctionSpace(mesh, AFW_elem, variant="alfeld")
        DG = FunctionSpace(mesh, "DG", 0, variant="alfeld")
        W = AFW * DG_vec * DG
        sigma, u_0, gamma = TrialFunctions(W)
        tau,   v,   eta   = TestFunctions(W)
    else:
        raise ValueError(f"Unknown scheme '{scheme}'. Choose 'JM' or 'AFW'.")

    # LHS
    a = (
        inner(A_comp(sigma), tau)
      + inner(u_0, div(tau))
      + inner(div(sigma), v)
    ) * dx
    if scheme == "AFW":
        def asym2d(tau): return tau[0, 1] - tau[1, 0]
        a += (
            inner(gamma, asym2d(tau))
          + inner(asym2d(sigma), eta)
        ) * dx

    # RHS
    x_var = variable(x)
    phi = - shear/2 * cos(pi * x_var / length)
    phi_prime = diff(phi, x_var)
    u_BC = as_vector([(y - height/2) * phi_prime, phi])
    L = (
        inner(sym(grad(u_BC)), tau)
      + grav * inner(as_vector([0,1]), v)
     ) * dx

    # Boundary conditions
    bcs = [
        DirichletBC(W.sub(0), 0, surf)
        for surf in free_surf
    ]

    # Solve
    w = Function(W)
    solve(a == L, w, bcs=bcs)

    # Output
    sigma, u_0 = w.subfunctions[0:2]
    if scheme == "AFW":
        gamma = w.subfunctions[2]

    s00 = sigma[0, 0]
    s11 = sigma[1, 1]
    s01 = (sigma[0, 1] + sigma[1, 0]) / 2
    sig_vm = sqrt(s00**2 - s00*s11 + s11**2 + 3*s01**2)
    sig_vm_dg = Function(FunctionSpace(mesh, "DG", 0), name="Von Mises stress (DG0)").project(sig_vm)
    sig_vm_cg = Function(FunctionSpace(mesh, "CG", 1), name="Von Mises stress (CG1)").project(sig_vm)

    u = Function(DG_vec, name="u (Alfeld-split DG0)").project(u_BC + u_0)
    u_cg = Function(VectorFunctionSpace(mesh, "CG", 1), name="u (CG1)").project(u)

    if scheme == "JM":
        return sigma, (u, u_cg), (sig_vm_dg, sig_vm_cg), mesh
    else:
        return sigma, (u, u_cg), (sig_vm_dg, sig_vm_cg), mesh, gamma

# %%
def plot_solution(u_cg, sig_vm_cg, mesh):
    """Plot vertical displacement and von Mises stress."""
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(12, 3))

    # Vertical displacement
    c0 = tripcolor(u_cg.sub(1), axes=axes[0], cmap="RdBu_r")
    plt.colorbar(c0, ax=axes[0], label=r"$u_y$")
    # axes[0].set_aspect("equal")
    axes[0].set_title("Vertical displacement")

    # Von Mises stress
    c1 = tripcolor(sig_vm_cg, axes=axes[1], cmap="inferno")
    plt.colorbar(c1, ax=axes[1], label=r"$\sigma_\mathrm{vM}$")
    # axes[1].set_aspect("equal")
    axes[1].set_title("Von Mises stress")

    plt.tight_layout()
    plt.show()

# %%
def plot_deformation(u_cg, sig_vm_dg, mesh):
    """Plot deformed mesh (coloured by von Mises stress)."""
    import matplotlib.pyplot as plt
    import matplotlib.tri as mtri

    coords = mesh.coordinates.dat.data_ro
    cells  = mesh.coordinates.cell_node_map().values
    disp   = u_cg.dat.data_ro

    triang_ref = mtri.Triangulation(coords[:, 0], coords[:, 1], cells)
    triang_def = mtri.Triangulation(
        coords[:, 0] + disp[:, 0],
        coords[:, 1] + disp[:, 1],
        cells,
    )

    fig, ax = plt.subplots(figsize=(10, 3))
    tc = ax.tripcolor(triang_def, facecolors=sig_vm_dg.dat.data_ro, cmap="inferno")
    plt.colorbar(tc, ax=ax, label=r"$\sigma_\mathrm{vM}$")
    ax.triplot(triang_ref, color="k", linewidth=0.3, alpha=0.2, label="Original")
    # ax.set_aspect("equal")
    ax.legend()
    ax.set_title(f"Deformed mesh (von Mises stress)")

    plt.tight_layout()
    plt.show()

# %%
def diagnostics(sigma, mesh, length, height, gamma=None, show=True):
    """Print resultant forces on the left (clamped) and right (free) faces."""
    n = FacetNormal(mesh)
    scale = (length/height)**3
    if show: print(BLUE % f"Scaled forces:")
    for label, marker in [(" Left", 1), ("Right", 2)]:
        Fx = scale * assemble(dot(sigma, n)[0] * ds(marker))
        Fy = scale * assemble(dot(sigma, n)[1] * ds(marker))
        if show: print(BLUE % f"  • {label} = ({Fx:+.6g}, {Fy:+.6g})")

    print()

    if gamma is not None:
        gamma_norm = sqrt(assemble(inner(gamma, gamma) * dx) / (length * height))
        # if show: print(RED % f"Normalised gamma norm = {gamma_norm:.6g}")
        return Fx, Fy, gamma_norm
    else:
        return Fx, Fy

# %%
def run_and_plot(scheme="JM", params=None):
    if scheme not in {"JM", "AFW"}:
        raise ValueError(f"Unknown scheme '{scheme}'. Choose 'JM' or 'AFW'.")
    if scheme=="JM":
        sigma, (u, u_cg), (sig_vm_dg, sig_vm_cg), mesh = solve_elasticity("JM", **params)
    else:
        sigma, (u, u_cg), (sig_vm_dg, sig_vm_cg), mesh, gamma = solve_elasticity("AFW", **params)
    # plot_solution(u_cg, sig_vm_cg, mesh)
    plot_deformation(u_cg, sig_vm_dg, mesh)
    if scheme=="JM":
        diagnostics(sigma, mesh, params["length"], params["height"])
    else:
        diagnostics(sigma, mesh, params["length"], params["height"], gamma=gamma)

# %%
def find_stress(scheme="JM", params=None):
    if scheme not in {"JM", "AFW"}:
        raise ValueError(f"Unknown scheme '{scheme}'. Choose 'JM' or 'AFW'.")
    output = solve_elasticity(scheme, **params)
    diag = diagnostics(output[0], output[3], params["length"], params["height"], show=False)
    return diag[1]

# %% [markdown]
# ## **Shear / Bending test**

# %%
model_params = {
    "length" : 5.0,
    "height" : 1.0,
    "nu" : 0.3,
}

disc_params = {
    "nx" : 10,
    "ny" : 10,
}

params = model_params | disc_params

# %%
run_and_plot(scheme="JM", params=params)
# Out:
# Scaled forces:
#   •  Left = (+0.00298016, -0.97237)
#   • Right = (-0.00298016, +0.97237)

# %%
run_and_plot(scheme="AFW", params=params)
# Out:
# Scaled forces:
#   •  Left = (-0.00159297, -1.0438)
#   • Right = (+0.00159297, +1.0438)
#
# Normalised gamma norm = 0.204729

# %% [markdown]
# Some simple elasticity theory tell us the shear force on the ends of the beam scale like
#
# $$
#     \mathbf{F}\cdot\mathbf{e}_2 \propto \frac{\varepsilon H^3}{L^3}.
# $$
#
# - More strain $\implies$ More stress
# - Thicker beam $\implies$ (Much) more stress
# - Long beam $\implies$ (Much) less stress
#
# All very intuitive!
# "Scaled forces" thus evaluates
#
# $$
#     \frac{L^3}{\varepsilon H^3}\mathbf{F},
# $$
#
# which should converge.
# So let's try making the beam longer...

# %%
run_and_plot(scheme="JM", params=params|{"length":100.0})
# Out:
# Scaled forces:
#   •  Left = (+3.92303e-06, -1.0983)
#   • Right = (-3.92302e-06, +1.0983)

# %%
run_and_plot(scheme="AFW", params=params|{"length":100.0})
# Out:
# Scaled forces:
#   •  Left = (+0.00612603, -3.10698)
#   • Right = (-0.00612603, +3.10698)

# %% [markdown]
# These shear stresses are very different? Maybe they're converging, but to different limits?
#
# Let's try a bunch of different lengths...

# %%
length_arr = [10.0**(i/5) for i in range(0,16)]

# %%
results = {scheme: [] for scheme in ("AFW", "JM")}
for scheme in ("AFW", "JM"):
    print(BLUE % f"Starting {scheme} tests...\n")
    for length in length_arr:
        print(GREEN % f"Solving at length {length:.1f}...")
        results[scheme].append(find_stress(scheme=scheme, params=params|{"length":length}))

fig, ax = plt.subplots(figsize=(7, 4))
for scheme, color, marker in (("AFW", "red", "s"), ("JM", "green", "o")):
    ax.plot(length_arr, results[scheme], color=color, marker=marker, label=scheme)
bend_mod = 1 / (1 - params["nu"]**2)
ax.plot([length_arr[0], length_arr[-1]], [bend_mod, bend_mod], "--", color="black", marker="none", label="Exact limit (bending modulus)")
ax.set_xscale("log")
ax.set_xlabel("Length")
ax.set_ylim(bottom=0)
ax.set_ylabel(r"Scaled shear stress")
ax.set_title("Beam shear stress in AFW vs. JM")
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We can actually solve exactly for the limit in this simple model:
#
# $$
#     \mathbf{F}\cdot\mathbf{e}_2 \sim \frac{1}{1 - \nu^2}\cdot\frac{\varepsilon H^3}{L^3}.
# $$
#
# Plotting this limit in the above figure, we see JM greatly outperforms AFW.
#
# - AFW (weakly symmetric) is much more stiff under bending than it should be
# - JM (strongly symmetric) is not
#
# *Why is this?*
